# %%
DEBUG=Flase

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense
from tensorflow.contrib.learn.python.learn.estimators._sklearn import train_test_split

import numpy as np
import cv2
import sys
import os
# Out:
# Using TensorFlow backend.

# %%
cap = cv2.VideoCapture('./video/none_256_5_mix.mp4')
if (cap.isOpened()== False): 
  print("Error opening video stream or file")

# %%
NO_OF_FRAMES=1010
FRAMES_TO_SKIP=10
'''NO_OF_FRAMES=int(sys.argv[1])
'''
FRAME_HEIGHT=1080
FRAME_WIDTH=1920
COLOR_CHANNELS=3

CELLS_PER_FRAME=9

EPOCHS=10
BATCH_SIZE=64
CUDA1=0
CUDA2=1

os.environ["CUDA_VISIBLE_DEVICES"]="{},{}".format(CUDA1,CUDA2)


'''EPOCHS=int(sys.argv[2])
BATCH_SIZE=int(sys.argv[3])
CUDA1=int(sys.argv[4])
CUDA2=int(sys.argv[5])'''
# Out:
# 'EPOCHS=int(sys.argv[2])\nBATCH_SIZE=int(sys.argv[3])\nCUDA1=int(sys.argv[4])\nCUDA2=int(sys.argv[5])'

# %%
'''while(cap.isOpened()):
  ret, frame = cap.read()
  if ret == True:
    cv2.imshow('Frame',frame)
    if cv2.waitKey(25) & 0xFF == ord('q'):
      break
  else: 
    break'''
# Out:
# "while(cap.isOpened()):\n  ret, frame = cap.read()\n  if ret == True:\n    cv2.imshow('Frame',frame)\n    if cv2.waitKey(25) & 0xFF == ord('q'):\n      break\n  else: \n    break"

# %%
def makeX(cap):
    ret,frame=cap.read()
    '''if (len(sys.argv)>1):
        NO_OF_FRAMES=int(sys.argv[1])'''

    X=np.zeros((NO_OF_FRAMES,FRAME_HEIGHT,FRAME_WIDTH,COLOR_CHANNELS))
        
    for f in range(NO_OF_FRAMES):
        X[f,:,:,:]=frame
        ret,frame=cap.read()

        '''if f%1 == 0:
            print(len(X[f,:,4,1]))'''
    
    return X
#maxeX(cap)

# %%
def makeY():
    import pandas as pd
    df=pd.read_csv('./video/none_256_5_mix.csv', sep=',',header=None)
    df=np.array(df)
    df=df[:NO_OF_FRAMES,1]
    
    Y=np.zeros((NO_OF_FRAMES,CELLS_PER_FRAME),dtype=np.int32)
    
    for f in range(NO_OF_FRAMES):
        if DEBUG: print("DEBUG: df=",df[f])
        for c in range(CELLS_PER_FRAME-1,-1,-1):
            Y[f,c]=int(df[f]/(2**c))
            if Y[f,c]>0:
                df[f]=df[f]-2**c
        
        if DEBUG: print("DEBUG: Y=",Y[f,:])
    
    return Y
    
#makeY()

# %%
X=makeX(cap)
Y=makeY()
X=X[FRAMES_TO_SKIP:]
Y=Y[FRAMES_TO_SKIP:]

if DEBUG: print("X= ",X)

if DEBUG: print("NAN in X",np.argwhere(np.isnan(X)))
if DEBUG: print("NAN in Y",np.argwhere(np.isnan(Y)))


if DEBUG: print("X shape: ",np.shape(X))
if DEBUG: print("Y shape: ",np.shape(Y))

INPUT_DIM=X[0].shape
OUTPUT_DIM=CELLS_PER_FRAME
# Out:
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 0
# DEBUG: Y= [0 0 0 0 0 0 0 0 0]
# DEBUG: df= 474
# DEBUG: Y= [0 1 0 1 1 0 1 1 1]
# DEBUG: df= 84
# DEBUG: Y= [0 0 1 0 1 0 1 0 0]
# DEBUG: df= 58
# DEBUG: Y= [0 1 0 1 1 1 0 0 0]
# DEBUG: df= 460
# DEBUG: Y= [0 0 1 1 0 0 1 1 1]
# DEBUG: df= 336
# DEBUG: Y= [0 0 0 0 1 0 1 0 1]
# DEBUG: df= 458
# DEBUG: Y= [0 1 0 1 0 0 1 1 1]
# DEBUG: df= 103
# DEBUG: Y= [1 1 1 0 0 1 1 0 0]
# DEBUG: df= 241
# DEBUG: Y= [1 0 0 0 1 1 1 1 0]
# DEBUG: df= 503
# DEBUG: Y= [1 1 1 0 1 1 1 1 1]
# DEBUG: df= 282
# DEBUG: Y= [0 1 0 1 1 0 0 0 1]
# DEBUG: df= 189
# DEBUG: Y= [1 0 1 1 1 1 0 1 0]
# DEBUG: df= 485
# DEBUG: Y= [1 0 1 0 0 1 1 1 1]
# DEBUG: df= 79
# DEBUG: Y= [1 1 1 1 0 0 1 0 0]
# DEBUG: df= 107
# DEBUG: Y= [1 1 0 1 0 1 1 0 0]
# DEBUG: df= 31
# DEBUG: Y= [1 1 1 1 1 0 0 0 0]
# DEBUG: df= 72
# DEBUG: Y= [0 0 0 1 0 0 1 0 0]
# DEBUG: df= 440
# DEBUG: Y= [0 0 0 1 1 1 0 1 1]
# DEBUG: df= 237
# DEBUG: Y= [1 0 1 1 0 1 1 1 0]
# DEBUG: df= 326
# DEBUG: Y= [0 1 1 0 0 0 1 0 1]
# DEBUG: df= 232
# DEBUG: Y= [0 0 0 1 0 1 1 1 0]
# DEBUG: df= 145
# DEBUG: Y= [1 0 0 0 1 0 0 1 0]
# DEBUG: df= 131
# DEBUG: Y= [1 1 0 0 0 0 0 1 0]
# DEBUG: df= 466
# DEBUG: Y= [0 1 0 0 1 0 1 1 1]
# DEBUG: df= 461
# DEBUG: Y= [1 0 1 1 0 0 1 1 1]
# DEBUG: df= 504
# DEBUG: Y= [0 0 0 1 1 1 1 1 1]
# DEBUG: df= 429
# DEBUG: Y= [1 0 1 1 0 1 0 1 1]
# DEBUG: df= 161
# DEBUG: Y= [1 0 0 0 0 1 0 1 0]
# DEBUG: df= 347
# DEBUG: Y= [1 1 0 1 1 0 1 0 1]
# DEBUG: df= 396
# DEBUG: Y= [0 0 1 1 0 0 0 1 1]
# DEBUG: df= 339
# DEBUG: Y= [1 1 0 0 1 0 1 0 1]
# DEBUG: df= 160
# DEBUG: Y= [0 0 0 0 0 1 0 1 0]
# DEBUG: df= 164
# DEBUG: Y= [0 0 1 0 0 1 0 1 0]
# DEBUG: df= 147
# DEBUG: Y= [1 1 0 0 1 0 0 1 0]
# DEBUG: df= 7
# DEBUG: Y= [1 1 1 0 0 0 0 0 0]
# DEBUG: df= 87
# DEBUG: Y= [1 1 1 0 1 0 1 0 0]
# DEBUG: df= 198
# DEBUG: Y= [0 1 1 0 0 0 1 1 0]
# DEBUG: df= 29
# DEBUG: Y= [1 0 1 1 1 0 0 0 0]
# DEBUG: df= 74
# DEBUG: Y= [0 1 0 1 0 0 1 0 0]
# DEBUG: df= 59
# DEBUG: Y= [1 1 0 1 1 1 0 0 0]
# DEBUG: df= 240
# DEBUG: Y= [0 0 0 0 1 1 1 1 0]
# X=  [[[[64. 55. 75.]
#    [64. 55. 75.]
#    [65. 56. 76.]
#    ...
#    [65. 46. 43.]
#    [65. 46. 43.]
#    [65. 46. 43.]]
#
#   [[64. 55. 75.]
#    [64. 55. 75.]
#    [65. 56. 76.]
#    ...
#    [65. 46. 43.]
#    [65. 46. 43.]
#    [65. 46. 43.]]
#
#   [[64. 55. 75.]
#    [64. 55. 75.]
#    [65. 56. 76.]
#    ...
#    [65. 46. 43.]
#    [65. 46. 43.]
#    [65. 46. 43.]]
#
#   ...
#
#   [[62. 45. 42.]
#    [62. 45. 42.]
#    [62. 45. 42.]
#    ...
#    [58. 37. 34.]
#    [58. 37. 34.]
#    [58. 37. 34.]]
#
#   [[62. 45. 42.]
#    [62. 45. 42.]
#    [62. 45. 42.]
#    ...
#    [58. 37. 34.]
#    [58. 37. 34.]
#    [58. 37. 34.]]
#
#   [[62. 45. 42.]
#    [62. 45. 42.]
#    [62. 45. 42.]
#    ...
#    [58. 37. 34.]
#    [58. 37. 34.]
#    [58. 37. 34.]]]
#
#
#  [[[61. 53. 71.]
#    [61. 53. 71.]
#    [62. 54. 72.]
#    ...
#    [62. 43. 40.]
#    [62. 43. 40.]
#    [62. 43. 40.]]
#
#   [[61. 53. 71.]
#    [61. 53. 71.]
#    [62. 54. 72.]
#    ...
#    [62. 43. 40.]
#    [62. 43. 40.]
#    [62. 43. 40.]]
#
#   [[60. 52. 70.]
#    [60. 52. 70.]
#    [61. 53. 71.]
#    ...
#    [62. 43. 40.]
#    [62. 43. 40.]
#    [62. 43. 40.]]
#
#   ...
#
#   [[59. 42. 39.]
#    [59. 42. 39.]
#    [59. 42. 39.]
#    ...
#    [70. 49. 46.]
#    [70. 49. 46.]
#    [70. 49. 46.]]
#
#   [[59. 42. 39.]
#    [59. 42. 39.]
#    [59. 42. 39.]
#    ...
#    [70. 49. 46.]
#    [70. 49. 46.]
#    [70. 49. 46.]]
#
#   [[59. 42. 39.]
#    [59. 42. 39.]
#    [59. 42. 39.]
#    ...
#    [70. 49. 46.]
#    [70. 49. 46.]
#    [70. 49. 46.]]]
#
#
#  [[[51. 43. 61.]
#    [52. 44. 62.]
#    [53. 45. 63.]
#    ...
#    [49. 30. 27.]
#    [49. 30. 27.]
#    [49. 30. 27.]]
#
#   [[51. 43. 61.]
#    [52. 44. 62.]
#    [52. 44. 62.]
#    ...
#    [49. 30. 27.]
#    [49. 30. 27.]
#    [49. 30. 27.]]
#
#   [[50. 42. 60.]
#    [51. 43. 61.]
#    [52. 44. 62.]
#    ...
#    [49. 30. 27.]
#    [49. 30. 27.]
#    [49. 30. 27.]]
#
#   ...
#
#   [[65. 46. 43.]
#    [65. 46. 43.]
#    [65. 46. 43.]
#    ...
#    [55. 36. 38.]
#    [55. 36. 38.]
#    [55. 36. 38.]]
#
#   [[65. 46. 43.]
#    [65. 46. 43.]
#    [65. 46. 43.]
#    ...
#    [55. 36. 38.]
#    [55. 36. 38.]
#    [55. 36. 38.]]
#
#   [[65. 46. 43.]
#    [65. 46. 43.]
#    [65. 46. 43.]
#    ...
#    [55. 36. 38.]
#    [55. 36. 38.]
#    [55. 36. 38.]]]
#
#
#  ...
#
#
#  [[[46. 38. 67.]
#    [46. 38. 67.]
#    [46. 38. 67.]
#    ...
#    [72. 25. 20.]
#    [73. 26. 21.]
#    [73. 26. 21.]]
#
#   [[47. 39. 68.]
#    [47. 39. 68.]
#    [47. 39. 68.]
#    ...
#    [72. 25. 20.]
#    [73. 26. 21.]
#    [73. 26. 21.]]
#
#   [[50. 40. 69.]
#    [51. 41. 70.]
#    [50. 40. 69.]
#    ...
#    [72. 25. 20.]
#    [73. 26. 21.]
#    [73. 26. 21.]]
#
#   ...
#
#   [[ 6.  9. 25.]
#    [ 6.  9. 25.]
#    [ 6.  9. 25.]
#    ...
#    [86. 38. 36.]
#    [86. 38. 36.]
#    [86. 38. 36.]]
#
#   [[ 6.  9. 25.]
#    [ 6.  9. 25.]
#    [ 6.  9. 25.]
#    ...
#    [86. 38. 36.]
#    [86. 38. 36.]
#    [86. 38. 36.]]
#
#   [[ 6.  9. 25.]
#    [ 6.  9. 25.]
#    [ 6.  9. 25.]
#    ...
#    [86. 38. 36.]
#    [86. 38. 36.]
#    [86. 38. 36.]]]
#
#
#  [[[45. 37. 71.]
#    [45. 37. 71.]
#    [45. 37. 71.]
#    ...
#    [70. 23. 18.]
#    [70. 23. 18.]
#    [70. 23. 18.]]
#
#   [[45. 37. 71.]
#    [45. 37. 71.]
#    [45. 37. 71.]
#    ...
#    [70. 23. 18.]
#    [70. 23. 18.]
#    [70. 23. 18.]]
#
#   [[47. 37. 71.]
#    [47. 37. 71.]
#    [47. 37. 71.]
#    ...
#    [70. 23. 18.]
#    [70. 23. 18.]
#    [70. 23. 18.]]
#
#   ...
#
#   [[ 8. 10. 31.]
#    [ 8. 10. 31.]
#    [ 8. 10. 31.]
#    ...
#    [86. 39. 35.]
#    [86. 39. 35.]
#    [86. 39. 35.]]
#
#   [[ 8. 10. 31.]
#    [ 8. 10. 31.]
#    [ 8. 10. 31.]
#    ...
#    [86. 39. 35.]
#    [86. 39. 35.]
#    [86. 39. 35.]]
#
#   [[ 8. 10. 31.]
#    [ 8. 10. 31.]
#    [ 8. 10. 31.]
#    ...
#    [86. 39. 35.]
#    [86. 39. 35.]
#    [86. 39. 35.]]]
#
#
#  [[[59. 50. 86.]
#    [59. 50. 86.]
#    [59. 50. 86.]
#    ...
#    [72. 27. 17.]
#    [72. 27. 17.]
#    [72. 27. 17.]]
#
#   [[59. 50. 86.]
#    [59. 50. 86.]
#    [60. 51. 87.]
#    ...
#    [72. 27. 17.]
#    [72. 27. 17.]
#    [72. 27. 17.]]
#
#   [[61. 50. 86.]
#    [62. 51. 87.]
#    [62. 51. 87.]
#    ...
#    [72. 27. 17.]
#    [72. 27. 17.]
#    [72. 27. 17.]]
#
#   ...
#
#   [[26. 25. 39.]
#    [27. 26. 40.]
#    [28. 27. 41.]
#    ...
#    [65. 25. 25.]
#    [66. 22. 26.]
#    [66. 22. 26.]]
#
#   [[26. 25. 39.]
#    [27. 26. 40.]
#    [28. 27. 41.]
#    ...
#    [65. 25. 25.]
#    [66. 22. 26.]
#    [66. 22. 26.]]
#
#   [[26. 25. 39.]
#    [27. 26. 40.]
#    [28. 27. 41.]
#    ...
#    [65. 25. 25.]
#    [66. 22. 26.]
#    [66. 22. 26.]]]]
# NAN in X []
# NAN in Y []
# X shape:  (40, 1080, 1920, 3)
# Y shape:  (40, 9)

# %%
'''Preparing the input and output vectors'''
X=np.mean(X,axis=3)
X=np.reshape(X,(X.shape[0],X.shape[1],X.shape[2],1))


print("X shape {}, Y shape {}.".format(X.shape,Y.shape))

xTrain, xTest, yTrain, yTest= train_test_split(X, Y, test_size=0.2)
# Out:
# X shape (40, 1080, 1920, 1), Y shape (40, 9).

# %%
def cnn(inptuDim,outputDim):
    model=Sequential()
    model.add(Conv2D(5, kernel_size=(2,2), activation='relu',strides=(2,2)))
    model.add(Conv2D(5, kernel_size=(2,2), activation='relu',strides=(2,2)))
    model.add(Conv2D(5, kernel_size=(2,2), activation='relu',strides=(2,2)))
    model.add(Conv2D(5, kernel_size=(2,2), activation='relu',strides=(2,2)))
    model.add(Conv2D(5, kernel_size=(2,2), activation='relu',strides=(2,2)))
    model.add(Conv2D(5, kernel_size=(2,2), activation='relu',strides=(2,2)))
    model.add(Flatten())
    #model.add(Dense(500,activation='relu'))
    #model.add(Dense(81,activation='sigmoid'))
    model.add(Dense((CELLS_PER_FRAME),activation='sigmoid'))

    return model

# %%
model=cnn(INPUT_DIM,OUTPUT_DIM)
model.build()
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['accuracy'])
model.fit(xTrain,yTrain,validation_split=0.3,epochs=EPOCHS,verbose=1,batch_size=BATCH_SIZE,shuffle=False)
print(model.summary())
# Out:
# Train on 22 samples, validate on 10 samples
# Epoch 1/10
# 22/22 [==============================] - 1s 53ms/step - loss: 0.3329 - acc: 0.0000e+00 - val_loss: 0.2803 - val_acc: 0.1000
# Epoch 2/10
# 22/22 [==============================] - 1s 41ms/step - loss: 0.2981 - acc: 0.0000e+00 - val_loss: 0.2785 - val_acc: 0.2000
# Epoch 3/10
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2658 - acc: 0.0455 - val_loss: 0.2821 - val_acc: 0.1000
# Epoch 4/10
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2454 - acc: 0.0909 - val_loss: 0.2872 - val_acc: 0.4000
# Epoch 5/10
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2322 - acc: 0.0455 - val_loss: 0.2919 - val_acc: 0.2000
# Epoch 6/10
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2231 - acc: 0.0455 - val_loss: 0.2955 - val_acc: 0.1000
# Epoch 7/10
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2162 - acc: 0.0455 - val_loss: 0.2980 - val_acc: 0.1000
# Epoch 8/10
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2102 - acc: 0.0455 - val_loss: 0.2996 - val_acc: 0.1000
# Epoch 9/10
# 22/22 [==============================] - 1s 42ms/step - loss: 0.2044 - acc: 0.0455 - val_loss: 0.3004 - val_acc: 0.0000e+00
# Epoch 10/10
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1986 - acc: 0.0000e+00 - val_loss: 0.3008 - val_acc: 0.0000e+00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 540, 960, 5)       25
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 270, 480, 5)       105
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 135, 240, 5)       105
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 67, 120, 5)        105
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 33, 60, 5)         105
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 30, 5)         105
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2400)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 9)                 21609
# =================================================================
# Total params: 22,159
# Trainable params: 22,159
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
print(model.evaluate(xTest,yTest,batch_size=BATCH_SIZE))
# Out:
# 8/8 [==============================] - 0s 24ms/step
# [0.27516549825668335, 0.0]

# %%
cap.release()
cv2.destroyAllWindows()
